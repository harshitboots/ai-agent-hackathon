# %%
# ==========================================================
#  DATA EXPLORATION NOTEBOOK
# ==========================================================
#  OBJECTIVE:
# - Understand dataset
# - Identify patterns
# - Select target variable
# - Prepare for feature engineering

# %%
# ==========================================================
# STEP 1 — LOAD LIBRARIES
# ==========================================================
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ==========================================================
# STEP 2 — LOAD DATA
# ==========================================================
df = pd.read_csv("../data/train.csv")

# View first 5 rows
df.head()
# Out:
#    customer_id  age  gender  country  tenure_months  monthly_spend  \
# 0         1502   59    Male  Germany              2     185.360890
# 1         2587   25  Female       US             54     108.879222
# 2         2654   38  Female  Germany             48     221.927474
# 3         1056   48    Male       US             26     275.346433
# 4          706   53    Male       UK             15     444.016783
#
#    num_transactions  last_login_days  support_tickets payment_method  \
# 0                52               18                5         PayPal
# 1                35               17                7           Card
# 2                 5                2                5         PayPal
# 3                14               26                5           Card
# 4                95               20                0           Card
#
#    is_active   total_spend  avg_transaction_value  target_churn  \
# 0          0    370.721781               6.994751             1
# 1          1   5879.477977             163.318833             0
# 2          1  10652.518741            1775.419790             0
# 3          1   7159.007247             477.267150             0
# 4          1   6660.251746              69.377622             0
#
#    target_revenue  target_fraud
# 0      382.034265             0
# 1      217.996705             1
# 2      208.955628             0
# 3      248.913546             0
# 4      768.714022             0

# %%
# ==========================================================
# STEP 3 — BASIC DATA INFO
# ==========================================================
#  Understand structure of dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            4000 non-null   int64
#  1   age                    4000 non-null   int64
#  2   gender                 4000 non-null   object
#  3   country                4000 non-null   object
#  4   tenure_months          4000 non-null   int64
#  5   monthly_spend          4000 non-null   float64
#  6   num_transactions       4000 non-null   int64
#  7   last_login_days        4000 non-null   int64
#  8   support_tickets        4000 non-null   int64
#  9   payment_method         4000 non-null   object
#  10  is_active              4000 non-null   int64
#  11  total_spend            4000 non-null   float64
#  12  avg_transaction_value  4000 non-null   float64
#  13  target_churn           4000 non-null   int64
#  14  target_revenue         4000 non-null   float64
#  15  target_fraud           4000 non-null   int64
# dtypes: float64(4), int64(9), object(3)
# memory usage: 500.1+ KB

# %%
# ==========================================================
# STEP 4 — SUMMARY STATISTICS
# ==========================================================
# Understand distributions of numerical features

df.describe()
# Out:
#        customer_id          age  tenure_months  monthly_spend  \
# count  4000.000000  4000.000000    4000.000000    4000.000000
# mean   2488.605000    43.617250      30.384500     260.287722
# std    1450.904584    14.898716      16.926866     140.170997
# min       1.000000    18.000000       1.000000      20.148671
# 25%    1234.750000    31.000000      16.000000     137.555345
# 50%    2469.500000    43.000000      30.000000     259.667856
# 75%    3758.250000    56.000000      45.000000     385.223986
# max    5000.000000    69.000000      59.000000     499.963917
#
#        num_transactions  last_login_days  support_tickets    is_active  \
# count       4000.000000      4000.000000      4000.000000  4000.000000
# mean          50.302750        14.871250         4.576000     0.512250
# std           28.807873         8.383093         2.864834     0.499912
# min            1.000000         1.000000         0.000000     0.000000
# 25%           25.000000         7.750000         2.000000     0.000000
# 50%           50.000000        15.000000         5.000000     1.000000
# 75%           75.000000        22.000000         7.000000     1.000000
# max           99.000000        29.000000         9.000000     1.000000
#
#         total_spend  avg_transaction_value  target_churn  target_revenue  \
# count   4000.000000            4000.000000   4000.000000     4000.000000
# mean    7960.363114             340.121649      0.130750      360.955385
# std     6640.229748             780.843767      0.337169      167.073984
# min       23.481165               0.635177      0.000000      -72.269245
# 25%     2488.727165              50.914208      0.000000      233.436835
# 50%     6071.102307             135.367022      0.000000      355.167988
# 75%    11931.715821             306.158449      0.000000      482.941425
# max    29408.316407           14598.959341      1.000000      843.213128
#
#        target_fraud
# count   4000.000000
# mean       0.171500
# std        0.376992
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
# ==========================================================
#  STEP 5 — CHECK MISSING VALUES
# ==========================================================
#  Check if data cleaning is required

df.isnull().sum()
# Out:
# customer_id              0
# age                      0
# gender                   0
# country                  0
# tenure_months            0
# monthly_spend            0
# num_transactions         0
# last_login_days          0
# support_tickets          0
# payment_method           0
# is_active                0
# total_spend              0
# avg_transaction_value    0
# target_churn             0
# target_revenue           0
# target_fraud             0
# dtype: int64

# %%
# ==========================================================
#  STEP 6 — DISTRIBUTION ANALYSIS
# ==========================================================
#  Understand spending behavior

plt.figure(figsize=(8,5))
sns.histplot(df["monthly_spend"], bins=30)
plt.title("Monthly Spend Distribution")
plt.show()

# %%
# ==========================================================
#  STEP 7 — CORRELATION ANALYSIS
# ==========================================================
#  Identify relationships between variables

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
# ==========================================================
#  IMPORTANT — CHOOSE YOUR TARGET
# ==========================================================
#  STUDENT TASK:
# Choose ONE target column based on your problem

# Options:
# - target_churn → Classification (0/1)
# - target_fraud → Classification (0/1)
# - target_revenue → Regression (continuous)

TARGET_COLUMN = "target_churn"   #  CHANGE THIS BASED ON YOUR TASK

# %%
# ==========================================================
#  STUDENT TASK 1
# ==========================================================
# Find top 3 features correlated with your target

#  Hint:
# df.corr(numeric_only=True)[TARGET_COLUMN].sort_values()

# Write your code below:
correlation = df.corr(numeric_only=True)[TARGET_COLUMN].sort_values(ascending=False)

top_3 = correlation[1:4]  # skip target itself (index 0)

print(top_3)
# Out:
# avg_transaction_value    0.125150
# last_login_days          0.061782
# age                      0.021962
# Name: target_churn, dtype: float64

# %%
# ==========================================================
#  STUDENT TASK 2
# ==========================================================
# Analyze relationship between age and monthly_spend

#  Hint:
# Use scatterplot or boxplot

# Write your code below:
plt.figure()
plt.scatter(df["total_spend"], df["monthly_spend"])
plt.xlabel("Total Spend")
plt.ylabel("Monthly Spend")
plt.title("Total Spend vs Monthly Spend")
plt.show()

# %%
# ==========================================================
#  STUDENT TASK 3
# ==========================================================
# Which country has highest churn rate?

#  Hint:
# groupby + mean

# Example:
# df.groupby("country")[TARGET_COLUMN].mean()

# Write your code below:

churn_by_country = df.groupby("country")[TARGET_COLUMN].mean()

# Sort to find highest churn rate
churn_by_country = churn_by_country.sort_values(ascending=False)

print(churn_by_country)
# Out:
# country
# India      0.142857
# Germany    0.136364
# US         0.123232
# UK         0.121469
# Name: target_churn, dtype: float64
